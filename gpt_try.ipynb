# %%
# openai_key='' # put your openai secret key here

# ! pwd
# ! echo "export OPENAI_API_KEY=$openai_key" >> ~/.zshrc
# ! source ~/.zshrc
# ! echo $OPENAI_API_KEY

# %%
import openai
import os
import IPython
import time
import json
from dotenv import load_dotenv
load_dotenv()
# openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_key ="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"

# %%
ICF_defs = {
 
    "mobility": "about moving by changing body position or location or by transferring from one place to another, by carrying, moving or manipulating objects, by walking, running or climbing, and by using various forms of transportation",

    "self-care": "about caring for oneself, washing and drying oneself, caring for one's body and body parts, dressing, eating and drinking, and looking after one's health",

    "communication": "about general and specific features of communicating by language, signs and symbols, including receiving and producing messages, carrying on conversations, and using communication devices and techniques"

            }

# %% [markdown]
# ## compare the with definition of subactivity and the one without them

# %%
## without 

ICF_cate_without = {
    "mobility":{
        "Walking": {"definition": "Moving along a surface on foot, step by step, so that one foot is always on the ground, such as when strolling, sauntering, walking forwards, backwards, or sideways.",
                   "sub_activity": "Walking distances, Walking on different surfaces, Walking around obstacles"
                   },
        "Going up and down stairs": {"definition":"Moving upwards and downwards so that at least one foot is always on the ground such as ascending and descending stairs or curbs."
                    },
        "Moving around": {"definition": "Moving the whole body from one place to another by means other than walking, such as climbing over a rock or running down a street, skipping, scampering, jumping, somersaulting or running around obstacles.",
                          "sub_activity": "Moving around while doing other activities such as lying and sitting"
                    },
        "Moving around in different locations": {"definition": "Walking and moving around in various places and situations, such as walking between rooms in a house, within a building, or down the street of a town.",
                                                 "sub_activity": "Moving around within the home, Moving around within buildings other than home, Moving around outside the home and other buildings"
                    },
    },

    
    "communication":{
        "Communicating with receiving spoken messages": {"definition":"Comprehending literal and implied meanings of messages in spoken language, such as understanding that a statement asserts a fact or is an idiomatic expression. ",
                                                         "sub_activity": "receiving simple spoken messages, receiving complex spoken messages, receiving human voice"
                                                            },
        "Communicating with receiving nonverbal messages":{"definition":"Comprehending the literal and implied meanings of messages conveyed by gestures, symbols and drawings, such as realizing that a child is tired when she rubs her eyes or that a warning bell means that there is a fire.",
                                                         "sub_activity": "receiving body gestures, receiving general signs and symbols, receiving drawings and photographs, other unspecified communicating with receiving nonverbal messages"
                                                            },
        "Communicating with receiving formal sign language messages":{"definition":"Receiving and comprehending messages in formal sign language with literal and implied meaning. ",
                                                         "sub_activity": ""
                                                            },
        "Communicating with receiving written messages":{"definition": "Comprehending the literal and implied meanings of messages that are conveyed through written language (including Braille), such as following political events in the daily newspaper or understanding the intent of religious scripture.",
                                                          "sub_activity": ""
                                                         },
        "Communicating with producing speech":{"definition": "Producing words, phrases and longer passages in spoken messages with literal and implied meaning, such as expressing a fact or telling a story in oral language. ",
                                               "sub_activity": ""
                                                         },
        "Non-speech vocal expression":{"definition": "Vocalising when aware of another person in the proximal environment, such as making a sound when the mother is close; babbling; babbling in turn-taking activities. Vocalising in response to speech through imitating speech-sounds in a turn taking procedure. ",
                                               "sub_activity": ""
                                                         },
        "Singing": {"definition": "Producing tones in a sequence resulting in a melody to convey messages. ",
                    "sub_activity":""
                    },
        "Producing nonverbal messages": {"definition": "Using gestures, symbols and drawings to convey messages, such as shaking one's head to indicate disagreement or drawing a picture or diagram to convey a fact or complex idea. ",
                    "sub_activity":"Producing body language, Producing signs and symbols, Producing drawings and photographs, Other specified producing nonverbal messages"
                    },
        "Producing messages in formal sign language": {"definition": "Conveying, with formal sign language, literal and implied meaning.",
                    "sub_activity":""
                                                      },
        "Writing messages": {"definition":"Producing the literal and implied meanings of messages that are conveyed through written language, such as writing a letter to a friend. ",
                             "sub_activity":""
                            },
        "Conversation":{"definition":"Starting, sustaining and ending an interchange of thoughts and ideas, carried out by means of spoken, written, signed or other forms of language, with one or more people one knows or who are strangers, in formal or casual settings. ",
                        "sub_activity":"Starting a conversation, Sustaining a conversation, Ending a conversation, Conversing with one person, Conversing with many people"
        },
        
        
        
    },

}

# %%
ICF_cate_with = {
    "mobility":{
        "Walking": {"definition": "Moving along a surface on foot, step by step, so that one foot is always on the ground, such as when strolling, sauntering, walking forwards, backwards, or sideways.",
                   "sub_activity": 
                    "Walking short distances: it means Walking for less than a kilometre, such as walking around rooms or hallways, within a building or for short distances outside; \
                    or Walking long distances: it means Walking for more than a kilometre, such as across a village or town, between villages or across open areas; \
                    or Walking on different surfaces: it means Walking on sloping, uneven, or moving surfaces, such as on grass, gravel or ice and snow, or walking aboard a ship, train or other vehicle;\
                    or Walking around obstacles: it means Walking in ways required to avoid moving and immobile objects, people, animals, and vehicles, such as walking around a marketplace or shop, around or through traffic or other crowded areas."
                   },
        "Going up and down stairs": {"definition":"Moving upwards and downwards so that at least one foot is always on the ground such as ascending and descending stairs or curbs."
                    },
        "Moving around": {"definition": "Moving the whole body from one place to another by means other than walking, such as climbing over a rock or running down a street, skipping, scampering, jumping, somersaulting or running around obstacles.",
                          "sub_activity": 
                          "Crawling: Moving the whole body in a prone position from one place to another on hands, or hands and arms, and knees;\
                          Climbing: Moving the whole body upwards or downwards, over surfaces or objects, such as climbing steps, rocks, ladders or stairs, curbs or other objects;\
                          Running: Moving with quick steps so that both feet may be simultaneously off the ground;\
                          Jumping: Moving up off the ground by bending and extending the legs, such as jumping on one foot, hopping, skipping and jumping or diving into water;\
                          Swimming: Propelling the whole body through water by means of limb and body movements without taking support from the ground underneath;\
                          Moving around while lying:Propelling the whole body from one place to another in a lying position without getting up;\
                          Moving around while sitting:Propelling the whole body from one place to another in a sitting position without getting up."
                    },
        "Moving around in different locations": {"definition": "Walking and moving around in various places and situations, such as walking between rooms in a house, within a building, or down the street of a town.",
                                                 "sub_activity": 
                                                 "Moving around within the home:Walking and moving around in one's home, within a room, between rooms, and around the whole residence or living area;\
                                                 Moving around within buildings other than home: Walking and moving around within buildings other than one's residence, such as moving around other people's homes, other private buildings, community and public buildings and enclosed areas;\
                                                 Moving around outside the home and other buildings:  Walking and moving around close to or far from one's home and other buildings, without the use of transportation, public or private, such as walking for short or long distances around a town or village."
                    },
    },

    
    "communication":{
        "Communicating with receiving spoken messages": {"definition":"Comprehending literal and implied meanings of messages in spoken language, such as understanding that a statement asserts a fact or is an idiomatic expression. ",
                                                         "sub_activity": 
                                                         "receiving simple,  spoken messages:Comprehending the literal meaning conveyed by simple spoken messages;\
                                                         receiving complex spoken messages:Comprehending the literal and implied meaning conveyed by complex spoken messages;\
                                                         receiving human voice: Comprehending the human voice in a very basic manner"
                                                            },
        "Communicating with receiving nonverbal messages":{"definition":"Comprehending the literal and implied meanings of messages conveyed by gestures, symbols and drawings, such as realizing that a child is tired when she rubs her eyes or that a warning bell means that there is a fire.",
                                                         "sub_activity": 
                                                           "receiving body gestures: Comprehending the meaning conveyed by facial expressions, hand movements or signs, body postures, and other forms of body language;\
                                                           receiving general signs and symbols: Comprehending the meaning represented by public signs and symbols, such as traffic signs, warning symbols, musical or scientific notations, and icons;\
                                                           receiving drawings and photographs: Comprehending the meaning represented by drawings (e.g. line drawings, graphic designs, paintings, three-dimensional representations, pictograms), graphs, charts and photographs, such as understanding that an upward line on a height chart indicates that a child is growing."
                                                            },
        # "Communicating with receiving formal sign language messages":{"definition":"Receiving and comprehending messages in formal sign language with literal and implied meaning. ",
        #                                                  "sub_activity": ""
        #                                                     },
        # "Communicating with receiving written messages":{"definition": "Comprehending the literal and implied meanings of messages that are conveyed through written language (including Braille), such as following political events in the daily newspaper or understanding the intent of religious scripture.",
        #                                                   "sub_activity": ""
        #                                                  },
        # "Communicating with producing speech":{"definition": "Producing words, phrases and longer passages in spoken messages with literal and implied meaning, such as expressing a fact or telling a story in oral language. ",
        #                                        "sub_activity": ""
        #                                                  },
        # "Non-speech vocal expression":{"definition": "Vocalising when aware of another person in the proximal environment, such as making a sound when the mother is close; babbling; babbling in turn-taking activities. Vocalising in response to speech through imitating speech-sounds in a turn taking procedure. ",
        #                                        "sub_activity": ""
        #                                                  },
        # "Singing": {"definition": "Producing tones in a sequence resulting in a melody to convey messages. ",
        #             "sub_activity":""
        #             },
        "Producing nonverbal messages": {"definition": "Using gestures, symbols and drawings to convey messages, such as shaking one's head to indicate disagreement or drawing a picture or diagram to convey a fact or complex idea. ",
                    "sub_activity":
                    "Producing body language: Conveying messages by intentional movements of the body, such as facial gestures (e.g. smiling, frowning, wincing), by arm and hand movements, and by postures (e.g. embracing to indicate affection or pointing to receive attention or an object);\
                    Producing signs and symbols: Conveying meaning by using signs and symbols (e.g. icons, Bliss board, scientific symbols) and symbolic notation systems, such as using musical notation to convey a melody;\
                    Producing drawings and photographs: Conveying meaning by drawing, painting, sketching, and making diagrams, pictures or photographs, such as drawing a map to give someone directions to a location."
                    },
        "Producing messages in formal sign language": {"definition": "Conveying, with formal sign language, literal and implied meaning.",
                    "sub_activity":""
                                                      },
        "Writing messages": {"definition":"Producing the literal and implied meanings of messages that are conveyed through written language, such as writing a letter to a friend. ",
                             "sub_activity":""
                            },
        "Conversation":{"definition":"Starting, sustaining and ending an interchange of thoughts and ideas, carried out by means of spoken, written, signed or other forms of language, with one or more people one knows or who are strangers, in formal or casual settings. ",
                        "sub_activity":
                        "Starting a conversation: Beginning an interchange, such as initiating turn-taking activity through eye-contact or other means, that leads to communication or dialogue, such as by introducing oneself, expressing customary greetings, or by introducing a topic or asking questions/\
                        Sustaining a conversation: Continuing an interchange by taking turns in vocalising, speaking or signing, by adding ideas, introducing a new topic or retrieving a topic that has been previously mentioned;\
                        Ending a conversation: Finishing a dialogue or interchange with customary termination statements or expressions and by bringing closure to the topic under discussion;\
                        Conversing with one person: Initiating, maintaining, shaping and terminating a dialogue or interchange with one person, such as in pre-verbal or verbal play, vocal or verbal exchange between mother and child, or in discussing the weather with a friend;\
                        Conversing with many people:  Initiating, maintaining, shaping and terminating a dialogue or interchange with more than one individual, such as in starting and participating in a group interchange."
        },
        
        
        
    },

}

# %%
import os

# Define the directory path
directory = '../response_data/raw_conversations/'

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

print(f"Directory '{directory}' has been created or already exists.")
# Out:
# Directory '../response_data/raw_conversations/' has been created or already exists.

# %%
functions = ["mobility", "domestic life"]
# definition = ICF_defs[category]

# activity="walking"
# function = "mobility"



def category_trainset(function, ICF_defs, ICF_cate, withdefi=True, MODEL = "gpt-3.5-turbo", dir= '../response_data/raw_conversations/'):
    """
    
    """
    count = 0
    data = {f"{function}": []}  
    text2write = ""
    function_definition = ICF_defs[function]

    
    for activity, infor in ICF_cate[function].items():

        sub_activity = infor["sub_activity"]
        activity_definition = infor["definition"]
        
        if sub_activity != "":
            sub_activity_str = f"such as asking more in details about {sub_activity}"
        else:
            sub_activity_str = ""

        query = [
            {"role": "system", "content": "You need to play the roles of a care taker (C) and an elderly patient (P)"}, # roles to play
            {"role": "system", "content": """Generate one small and natural conversation about one activity and focus on asking three types of follow-up questions to monitor the function level related to that activity. The conversation has around 10 to 16 utterances in total and each utterance should be completed and has less than 20 tokens."""}, # conversation format and amount
            {"role": "system", "content": f"""The care taker first starts the conversation around the activity {activity} with 4-6 utterances, which means {activity_definition}. For example, when the activity is "walk", the conversation should be around "walk", being "C:'What did you do yesterday?' P:'I went to the cinema.' C:'How?' P:'By walk.'"
            """},
            {"role": "system", "content": f"""The conversation secondly has 6-12 utterances to ask three Follow-up questions (FQ) to monitor the function level of {function}, which is {function_definition}.  
            The questions should contain three types:
            The first FQ is to ask more specific questions about the {activity}, {sub_activity_str}. 
            The second FQ is to measure the performance level. Performance level refers to how well the activity is performed (observable),e.g., how long an activity took, whether assistance was needed.
            The third FQ is to measure the capacity level. Capacity level refers to patient's potential or feelings about the activity, e.g., perceived difficulty, physical demands.

            The format is as below, indicating the activity:

            C: starting conversation  (start the conversation around the activity)
            P: utterance (respond naturally)
            C: first type of FQ (ask more specific questions about the activity)
            P: utterance (respond naturally)
            C: second type of FQ (ask questions about performance level)
            P: utterance (respond naturally)
            C: third type of FQ (ask questions about capacity level)
            P: utterance (respond naturally)
            ...

            The overall conversation contain at least 10 utterances and must contain three types of questions about more subactivity about the activity, performance level and capacity level."""},
                {"role": "user", "content": f"The topic of the conversation is about {activity} and the patient can talk about his/her daily life which can reflect his/her functioning in {function}. In terms of functioning, {function} is about {function_definition}."}, # shifting details in the conversations
            ]

#         query = [
#                     {"role": "system", "content": "You need to play the roles of a care taker (C) and an elderly patient (P)"}, # roles to play
#                     {"role": "system", "content": """Generate one small and natural conversation about one activity and focus on asking three types of follow-up questions to monitor the function level related to that activity. The conversation has around 10 to 16 utterances in total and each utterance should be completed and has less than 20 tokens. 

#                     """}, # conversation format and amount
#                     {"role": "system", "content": f"""The care taker first starts the conversation around the activity {activity} with 4-6 utterances, which means {activity_definition}. For example, when the activity is "walk", the converstion should be around "walk", being "C:'What did you do yesterday?' P:'I went to the cinema.' C:'How?' P:'By walk.'"
#                     """},
#                     {"role": "system", "content": f"""The conversation secondly has 6-12 utterances to ask three Follow-up questions (FQ) to monitor the function level of {function}, which is {function_definition}.  
#                     the questions should contain three types:
#                     The first FQ is to ask more specific questions about the {activity}, such as {sub_activity}. 
#                     The second FQ is to measure the performance level. Performance level refers to how well the activity is performed (observable),e.g., how long an activity took, whether assistance was needed.
#                     The third FQ is to measure the capacity level. Capacity level refers to patient's potential or feelings about the activity, e.g., perceived difficulty, physical demands.

#                     The format is as below, indicating the activity:
                    
#                     C: starting conversation  (start the conversation around the activity)
#                     P: utternace (responde naturally)
#                     C: first type of FQ (ask more specific questions about the activity)
#                     P: utternace (responde naturally)
#                     C: second type of FQ (ask questions about performance level)
#                     P: utternace (responde naturally)
#                     C: third type of FQ (ask questions about capacity level)
#                     P: utternace (responde naturally)
#                     ...
                    
#                     The overall conversation contain at least 10 utterances and must contain three types of questions about more subactivity about the activity, performance level and capacity level.
#                     """},
#         #             genertaive question
#                     {"role": "user", "content": f"The topic of the conversation is about {activity} and the patient can talk about his/her daily life which can reflect his/her functioning in {function}. In terms of functioning, {function} is about {function_definition}."}, # shifting details in the conversations

#                     ]

        print(f"gpt-runing {function} - {activity}")
    
        response_query = openai.ChatCompletion.create(
        model=MODEL,
        messages=query,
        temperature=1.5,
        max_tokens = 150,
        n = 10,
        # request_timeout=240
        )

        print(f"gpt finished {function} - {activity}")
        
        # IPython.display.Markdown(response_query.choices[0]['message']['content'])
        time.sleep(60)
    
        for text in response_query.choices:
            conversation = text['message']['content']
            one_conversation = f'{activity}'+ '\n'+ conversation + '\n'+'-'*10 +'\n'
            data[f"{function}"].append(conversation)
            text2write += one_conversation
            count += 1
            
    if withdefi == True:
        subact_def = 'withdef'
    else:
        subact_def = 'without'

    with open (f'{dir}{function}{subact_def}.txt','w') as tfile:
        tfile.write(text2write)

    with open (f'{dir}{function}{subact_def}.json','w', encoding='utf-8') as jfile:
            json.dump(data,jfile, ensure_ascii=False, indent=4)

    print(f"generated {count} {function} conversations")
    print("-"*30)
    print("\n")

# %%
# make activity as the function instead of the function, and 




def category_trainset(function, ICF_defs, ICF_cate, withdefi=True, MODEL = "gpt-3.5-turbo", dir= '../response_data/raw_conversations/'):
    """
    
    """
    count = 0
    data = {f"{function}": []}  
    text2write = ""
    function_definition = ICF_defs[function]

    
    for activity, infor in ICF_cate[function].items():

        sub_activity = infor["sub_activity"]
        activity_definition = infor["definition"]
        
        if sub_activity != "":
            sub_activity_str = f"such as asking more in details about {sub_activity}"
        else:
            sub_activity_str = ""

        query = [
            {"role": "system", "content": "You need to play the roles of a care taker (C) and an elderly patient (P)"}, # roles to play
            {"role": "system", "content": """Generate one small and natural conversation about one activity and focus on asking three types of follow-up questions to monitor the function level related to that activity. The conversation has around 10 to 16 utterances in total and each utterance should be completed and has less than 20 tokens."""}, # conversation format and amount
            {"role": "system", "content": f"""The care taker first starts the conversation around the activity {activity} with 4-6 utterances, which means {activity_definition}. For example, when the activity is "walk", the conversation should be around "walk", being "C:'What did you do yesterday?' P:'I went to the cinema.' C:'How?' P:'By walk.'"
            """},
            {"role": "system", "content": f"""The conversation secondly has 6-12 utterances to ask three Follow-up questions (FQ) to monitor the function level of {function}, which is {function_definition}.  
            The questions should contain three types:
            The first FQ is to ask more specific questions about the {activity}, {sub_activity_str}. 
            The second FQ is to measure the performance level. Performance level refers to how well the activity is performed (observable),e.g., how long an activity took, whether assistance was needed.
            The third FQ is to measure the capacity level. Capacity level refers to patient's potential or feelings about the activity, e.g., perceived difficulty, physical demands.

            The format is as below, indicating the activity:

            C: starting conversation  (start the conversation around the activity)
            P: utterance (respond naturally)
            C: first type of FQ (ask more specific questions about the activity)
            P: utterance (respond naturally)
            C: second type of FQ (ask questions about performance level)
            P: utterance (respond naturally)
            C: third type of FQ (ask questions about capacity level)
            P: utterance (respond naturally)
            ...

            The overall conversation contain at least 10 utterances and must contain three types of questions about more subactivity about the activity, performance level and capacity level."""},
                {"role": "user", "content": f"The topic of the conversation is about {activity} and the patient can talk about his/her daily life which can reflect his/her functioning in {function}. In terms of functioning, {function} is about {function_definition}."}, # shifting details in the conversations
            ]

#         query = [
#                     {"role": "system", "content": "You need to play the roles of a care taker (C) and an elderly patient (P)"}, # roles to play
#                     {"role": "system", "content": """Generate one small and natural conversation about one activity and focus on asking three types of follow-up questions to monitor the function level related to that activity. The conversation has around 10 to 16 utterances in total and each utterance should be completed and has less than 20 tokens. 

#                     """}, # conversation format and amount
#                     {"role": "system", "content": f"""The care taker first starts the conversation around the activity {activity} with 4-6 utterances, which means {activity_definition}. For example, when the activity is "walk", the converstion should be around "walk", being "C:'What did you do yesterday?' P:'I went to the cinema.' C:'How?' P:'By walk.'"
#                     """},
#                     {"role": "system", "content": f"""The conversation secondly has 6-12 utterances to ask three Follow-up questions (FQ) to monitor the function level of {function}, which is {function_definition}.  
#                     the questions should contain three types:
#                     The first FQ is to ask more specific questions about the {activity}, such as {sub_activity}. 
#                     The second FQ is to measure the performance level. Performance level refers to how well the activity is performed (observable),e.g., how long an activity took, whether assistance was needed.
#                     The third FQ is to measure the capacity level. Capacity level refers to patient's potential or feelings about the activity, e.g., perceived difficulty, physical demands.

#                     The format is as below, indicating the activity:
                    
#                     C: starting conversation  (start the conversation around the activity)
#                     P: utternace (responde naturally)
#                     C: first type of FQ (ask more specific questions about the activity)
#                     P: utternace (responde naturally)
#                     C: second type of FQ (ask questions about performance level)
#                     P: utternace (responde naturally)
#                     C: third type of FQ (ask questions about capacity level)
#                     P: utternace (responde naturally)
#                     ...
                    
#                     The overall conversation contain at least 10 utterances and must contain three types of questions about more subactivity about the activity, performance level and capacity level.
#                     """},
#         #             genertaive question
#                     {"role": "user", "content": f"The topic of the conversation is about {activity} and the patient can talk about his/her daily life which can reflect his/her functioning in {function}. In terms of functioning, {function} is about {function_definition}."}, # shifting details in the conversations

#                     ]

        print(f"gpt-runing {function} - {activity}")
    
        response_query = openai.ChatCompletion.create(
        model=MODEL,
        messages=query,
        temperature=1.5,
        max_tokens = 150,
        n = 10,
        # request_timeout=240
        )

        print(f"gpt finished {function} - {activity}")
        
        # IPython.display.Markdown(response_query.choices[0]['message']['content'])
        time.sleep(60)
    
        for text in response_query.choices:
            conversation = text['message']['content']
            one_conversation = f'{activity}'+ '\n'+ conversation + '\n'+'-'*10 +'\n'
            data[f"{function}"].append(conversation)
            text2write += one_conversation
            count += 1
            
    if withdefi == True:
        subact_def = 'withdef'
    else:
        subact_def = 'without'

    with open (f'{dir}{function}{subact_def}.txt','w') as tfile:
        tfile.write(text2write)

    with open (f'{dir}{function}{subact_def}.json','w', encoding='utf-8') as jfile:
            json.dump(data,jfile, ensure_ascii=False, indent=4)

    print(f"generated {count} {function} conversations")
    print("-"*30)
    print("\n")

# %%
functions = ["mobility", "communication"]
for function in functions:
    category_trainset(function, ICF_defs, ICF_cate_without, withdefi = False)
print("done")
# Out:
# gpt-runing mobility - Walking
# gpt finished mobility - Walking
# gpt-runing mobility - Going up and down stairs
# gpt finished mobility - Going up and down stairs
# gpt-runing mobility - Moving around
# gpt finished mobility - Moving around
# gpt-runing mobility - Moving around in different locations
# gpt finished mobility - Moving around in different locations
# generated 40 mobility conversations
# ------------------------------
#
#
# gpt-runing communication - Communicating with receiving spoken messages
# gpt finished communication - Communicating with receiving spoken messages
# gpt-runing communication - Communicating with receiving nonverbal messages
# gpt finished communication - Communicating with receiving nonverbal messages
# gpt-runing communication - Communicating with receiving formal sign language messages
# gpt finished communication - Communicating with receiving formal sign language messages
# ...

# %%
functions = ["mobility", "communication"]
for function in functions:
    category_trainset(function, ICF_defs, ICF_cate_with)
print("done")
# Out:
# gpt-runing mobility - Walking
# gpt finished mobility - Walking
# gpt-runing mobility - Going up and down stairs
# gpt finished mobility - Going up and down stairs
# gpt-runing mobility - Moving around
# gpt finished mobility - Moving around
# gpt-runing mobility - Moving around in different locations
# gpt finished mobility - Moving around in different locations
# generated 40 mobility conversations
# ------------------------------
#
#
# gpt-runing communication - Communicating with receiving spoken messages
# gpt finished communication - Communicating with receiving spoken messages
# gpt-runing communication - Communicating with receiving nonverbal messages
# gpt finished communication - Communicating with receiving nonverbal messages
# gpt-runing communication - Producing nonverbal messages
# gpt finished communication - Producing nonverbal messages
# gpt-runing communication - Producing messages in formal sign language
# ...

# %%
category = "mobility"
definition = ICF_defs[category]
activity="walking"

query = [
            {"role": "system", "content": "You need to play the roles of a care taker (C) and an elderly patient (P)"}, # roles to play
            {"role": "system", "content": """Generate one small and natural conversation focusing on one activity and ask three types of follow-up questions to monitor the function related to that activity. The conversation has around 10 to 16 utterances in total and each utterance should be completed and has less than 20 tokens. 

            """}, # conversation format and amount
            {"role": "system", "content": """The care taker first starts the conversation around the activity "walking" with 4-6 utterances, which means "Moving along a surface on foot, step by step, so that one foot is always on the ground, such as when strolling, sauntering, walking forwards, backwards, or sideways.". For example, when the activity is "walk", the converstion should be around "walk", being "C:'What did you do yesterday?' P:'I went to the cinema.' C:'How?' P:'By walk.'"
            """},
            {"role": "system", "content": """The conversation secondly has 6-12 utterances to ask three Follow-up questions (FQ) to monitor the function level of "mobility", which is "about moving by changing body position or location or by transferring from one place to another, by carrying, moving or manipulating objects, by walking, running or climbing, and by using various forms of transportation".  
            It can be divided into three types:
            The first FQ is to ask more specific questions about the activity, such as "Walking short distances, Walking long distances, Walking on different surfaces, Walking around obstacles". 
            The second FQ is to measure the performance level. Performance level refers to how well the activity is performed (observable),e.g., how long an activity took, whether assistance was needed.
            The third FQ is to measure the capacity level. Capacity level refers to patient's potential or feelings about the activity, e.g., perceived difficulty, physical demands.
            
            The format is as below:
            C: utterance (start the conversation around the activity)
            P: utternace (responde naturally)
            C: utterance (ask more specific questions about the activity)
            P: utternace (responde naturally)
            C: utterance (ask questions about performance level)
            P: utternace (responde naturally)
            C: utterance (ask questions about capacity level)
            P: utternace (responde naturally)
            ...
            """},
#             genertaive question
            {"role": "user", "content": f"The topic of the conversation is about {activity} and the patient can talk about his/her daily life which can reflect his/her functioning in {category}. In terms of functioning, {category} is about {definition}."}, # shifting details in the conversations
            
            ]

# %%
category = "mobility"
definition = ICF_defs[category]
activity="walking"



query = [
            {"role": "system", "content": "You need to play the roles of a care taker (C) and an elderly patient (P)"}, # roles to play
            {"role": "system", "content": """Generate one small and natural conversation focusing on one activity and ask three types of follow-up questions to monitor the function related to that activity. The conversation has around 10 to 16 utterances in total and each utterance should be completed and has less than 20 tokens. 

            """}, # conversation format and amount
            {"role": "system", "content": """The care taker first starts the conversation around the activity "walking" with 4-6 utterances, which means "Moving along a surface on foot, step by step, so that one foot is always on the ground, such as when strolling, sauntering, walking forwards, backwards, or sideways.". For example, when the activity is "walk", the converstion should be around "walk", being "C:'What did you do yesterday?' P:'I went to the cinema.' C:'How?' P:'By walk.'"
            """},
            {"role": "system", "content": """The conversation secondly has 6-12 utterances to ask three Follow-up questions (FQ) to monitor the function level of "mobility", which is "about moving by changing body position or location or by transferring from one place to another, by carrying, moving or manipulating objects, by walking, running or climbing, and by using various forms of transportation".  
            It can be divided into three types:
            The first FQ is to ask more specific questions about the activity, such as "Walking short distances, Walking long distances, Walking on different surfaces, Walking around obstacles". 
            The second FQ is to measure the performance level. Performance level refers to how well the activity is performed (observable),e.g., how long an activity took, whether assistance was needed.
            The third FQ is to measure the capacity level. Capacity level refers to patient's potential or feelings about the activity, e.g., perceived difficulty, physical demands.
            
            The format is as below:
            C: utterance (start the conversation around the activity)
            P: utternace (responde naturally)
            C: utterance (ask more specific questions about the activity)
            P: utternace (responde naturally)
            C: utterance (ask questions about performance level)
            P: utternace (responde naturally)
            C: utterance (ask questions about capacity level)
            P: utternace (responde naturally)
            ...
            """},
#             genertaive question
            {"role": "user", "content": f"The topic of the conversation is about {activity} and the patient can talk about his/her daily life which can reflect his/her functioning in {category}. In terms of functioning, {category} is about {definition}."}, # shifting details in the conversations
            
            ]

# %%
def category_testset(category, definition, allevents, MODEL = "gpt-3.5-turbo", dir= '../response_data/raw_conversations/'):
    """
    This is to generate dialogues acccording to categories in ICF by feeding the definitions of the each category to the prompt
    """
    count = 0
    data = {f"{category}": []}  
    text2write = ""
    for subcategory, events in allevents[category].items():#category remains asls in the same call 

        query = [
            {"role": "system", "content": "Think as you are a real human."}, # Human
            {"role": "system", "content": """Generate one small and natural conversation without greetings by playing the roles of a friend (F) and an elderly patient (P). The conversation has around 10 to 30 utterances. Each utterance should be completed and has less than 20 tokens. The format is as below:
            F: utterance
            P: utternace
            F: utterance
            ...
            """}, # conversation format discription roles/
            #first turn
            {"role": "user", "content": f"The topic of the conversation is about {mobility} events. In terms of functioning, {mobility} is about {definition}. {mobility} events include {"walking and moving: walking, skating, jumping}."}, # shifting details in the conversations
            
            {"role": "user", "content": f"The patient can talk with the friend about his/her daily life which can reflect his/her functioning in {mobility}. The friend should ask when and how the event occurs. "}# descripe category with definitions (listing events)
            ]
        
        
#             second turn
            {"role": "user", "content": f"The topic of the conversation is about {mobility} events. In terms of functioning, {mobility} is about {definition}. {mobility} events include {"carrying, moving and handling objects: lifting, carrying"}."}, # shifting details in the conversations
            
            {"role": "user", "content": f"The patient can talk with the friend about his/her daily life which can reflect his/her functioning in {mobility}. The friend should ask when and how the event occurs. "}# descripe category with definitions (listing events)
            ]
    
    
    
        num_20 = ["self-care","community, social and civic life"]
        num_30 = ["general tasks and demands", "mobility"]
        num_40 = ["learning and applying knowledge", "communication", "domestic life", "major life areas"]
        num_60 = ["interpersonal interactions and relationships"]
        if category in num_20:
            num = 20
        elif category in num_30:
            num = 30
        elif category in num_40:
            num = 40
        elif category in num_60:
            num = 60
        else:
            print(f"no such category: {category}")

        print(f"gpt-runing {category} - {subcategory}")
        # MODEL = "gpt-3.5-turbo"
        response_query = openai.ChatCompletion.create(
        model=MODEL,
        messages=query,
        temperature=1.5,
        max_tokens = 150,
        n = num,
        )

        print(f"gpt finished {category} - {subcategory}")
        
        # IPython.display.Markdown(response_query.choices[0]['message']['content'])
        time.sleep(60)
    
        for text in response_query.choices:
            conversation = text['message']['content']
            one_conversation = conversation + '\n'+'-'*10 +'\n'
            data[f"{category}"].append(conversation)
            text2write += one_conversation
            count += 1

    with open (f'{dir}{category}.txt','w') as tfile:
        tfile.write(text2write)

    with open (f'{dir}{category}.json','w', encoding='utf-8') as jfile:
            json.dump(data,jfile, ensure_ascii=False, indent=4)

    print(f"generated {count} {category} conversations")
    print("-"*30)
    print("\n")

# %%
{"mobility": {
        "changing and maintaining body position": "getting up from a chair to lie down on a bed, getting into or out of sitting, standing, kneeling or squatting, maintaining seated, remaining standing and transfering oneself",

        "carrying, moving and handling objects": "lifting, carrying, kicking a ball, pushing bicycle pedal, using one's hands, fingers and thumbs, using one's hands and arms, and using one's foot and toes",

        "walking and moving": "walking, going up stairs, going down stairs, skipping, sacmpering, jummping, someraulting, skating, skiing, using a self-propelled wheelchair and walking with a walker",

        "moving around using transportation": "taking a taxi, bus, tram, train, subway, boat, airplane or a car, driving a car or a boat, riding a bike and riding a horse or a camel",
    }
}

# %%
# without examples
query = [
            {"role": "system", "content": """you will be provided with the conversation history about the activity related to the function of "domestic life" and you play the roles of a care-taker (F) and an elderly patient (P). When you play the care-taker, you ask follow-up questions for monitoring the function level and then you play the elderly patient to respond.
            The format is as below:
            F: utterance
            P: utterance
            F: utterance
            P: utterance
            """}, # Human
    
            {"role": "system", "content":"""Context: The dialogue revolves around the function category of "domestic life", which includes activities such as caring for one's belongings and space, acquiring food, clothing, and other necessities, household cleaning and repairing, and assisting others."""
            },
            {"role": "system", "content":"""Objective: As the care-taker (F), your goal is to ask two types of follow-up questions that monitor the function level of "domestic life" in terms of performance and capacity. Performance level refers to how well the activity is performed (observable), and capacity level refers to the patient's maximum potential or feelings about the activity (not physically observed).
            Performance Level: Observable actions, e.g., how long an activity took, whether assistance was needed.
            Capacity Level: Patient's potential or feelings about the activity, e.g., perceived difficulty, physical demands.
            Follow-up Questions should be able to know the performance and capacity levels such as: Mild Difficulty,Moderate Difficulty or Severe Difficulty."""
            },
            {"role": "system", "content":"""Use the following step-by-step instructions to generate new questions. For example, if a given conversaion is "F: How have you been managing these days? P: I've been busy arranging our new bookshelf in the living room. F: When did you buy the bookshelf? P: We bought it online last week and it arrived on Friday. F: That's nice! So, do you feel the living room looks more organized now? P: Definitely! It feels much neater and less cluttered. F: It's so satisfying when things are in order, right? Have any other plans for organizing your space? P: Planning to get new storage containers to arrange the kids' toys next.", 
            the follow-up questions can be "F: Have any other plans for organizing your space?" and "F: How confident do you feel about managing this task on your own? Would you say it’s slightly, moderately, or very challenging for you?",
            The following are step-by-step instructions to generate new questions.
            Step One: Focus on Recent Two Turns: "F: It's so satisfying when things are in order, right? Have any other plans for organizing your space? P: Planning to get new storage containers to arrange the kids' toys next."
                      the question is directly based on the patient's plan to organize the kids' toys.

            Step Two: Measure the Function Level of "Domestic Life": The question aims to assess the patient's ability to organize toys, which is a part of managing domestic life.

                      Ask Performance Level-related questions: By asking how confident the patient feels about managing the task on their own, I am probing their perceived performance level.

                      Ask Capacity Level-related questions: The question also seeks to understand the patient's capacity by gauging how challenging they find the task.Mild, Moderate, Severe:

                      The options "slightly, moderately, or very challenging" correspond to mild, moderate, and severe levels of difficulty.
            """            
            }
    
    
#             {"role": "user", "content": f"The topic of the conversation is about mobility events. In terms of functioning, mobility is about moving by changing body position or location or by transferring from one place to another, by carrying, moving or manipulating objects, by walking, running or climbing, and by using various forms of transportation"}, # shifting details in the conversations
            
#             {"role": "user", "content": f"The patient can talk with the friend about his/her daily life which can reflect his/her functioning in mobility. The friend should ask when and how the event occurs. "}# descripe category with definitions (listing events)
            ]

# %%
MODEL = "gpt-3.5-turbo"
response_query = openai.ChatCompletion.create(
model=MODEL,
messages=query,
temperature=1.5,
max_tokens = 150,
# n = num,
)
    # IPython.display.Markdown(response_query.choices[0]['message']['content'])
time.sleep(60)

for text in response_query.choices:
    conversation = text['message']['content']
    print(conversation)

# %%
query = [
            {"role": "system", "content": """you will be provided with the conversation history about the activity related to the function of mobility and you play the roles of a care-taker (F) and an elderly patient (P). When you play the care-taker, you ask follow-up questions for monitoring the function level and then you play the elderly patient to respond."
            The format is as below:
            F: utterance
            P: utterance
            F: utterance
            P: utterance"""}, # Human
             
            {"role": "system", "content": """Generate one small and natural conversation without greetings by playing the roles of a friend (F) and an elderly patient (P). The conversation has around 10 to 30 utterances. Each utterance should be completed and has less than 20 tokens. The format is as below:
            F: utterance
            P: utternace
            F: utterance
            ...
            """}, # conversation format discription roles/6
            
            {"role": "user", "content": f"The topic of the conversation is about mobility events. In terms of functioning, mobility is about moving by changing body position or location or by transferring from one place to another, by carrying, moving or manipulating objects, by walking, running or climbing, and by using various forms of transportation"}, # shifting details in the conversations
            
            {"role": "user", "content": f"The patient can talk with the friend about his/her daily life which can reflect his/her functioning in mobility. The friend should ask when and how the event occurs. "}# descripe category with definitions (listing events)
            ]

# %%
you will be provided with the conversation history about the activity related to the function of mobility and you play the roles of a care-taker (F) and an elderly patient (P). When you play the care-taker, you ask follow-up questions for monitoring the function level and then you play the elderly patient to respond.
The format is as below:
F: utterance
P: utterance
F: utterance

more specific requirement:

The dialogue revolves around the function category of mobility which includes activities such as caring for one's belongings and space, acquiring food, clothing, and other necessities, household cleaning and repairing, and assisting others.

Follow-up questions are to ask more specific questions to monitor the function level, in terms of the performance level and capacity level. When the conversation is segmented, you only need to consider the recent two turns as the history to generate the next question.

for a given conversation about "domestic life", its definition is about carrying out domestic and everyday actions and tasks. Areas of domestic life include caring for one's belongings and space, acquiring food, clothing and other necessities, household cleaning and repairing, caring for personal and other household objects, and assisting others",
the follow-up questions should:
1. focus on the recent two turns
2. ask questions to measure the function level of "domestic life", such as mild, moderate, severe performance, in terms of the performance level and capacity level.
3. performance level refers to measure how well the activity is performed.
4. capacity level refers to measure the user's maximum potential or the feeling about the activity such as “hardness”
5. difference between performance and capacity is that performance can be observed while capacity cannot.
6. performance and capacity level has been divided into three levels respectively. 
7. Ask a question to measure the function level or get the answer, describing the performance level of "MILD difficulty (slight, low)", "MODERATE performance difficulty (medium, fair)", "SEVERE performance difficulty (high, extreme)"


for example, 
1. given conversation: "F: How have you been managing these days? P: I've been busy arranging our new bookshelf in the living room. F: When did you buy the bookshelf? P: We bought it online last week and it arrived on Friday. F: That's nice! So, do you feel the living room looks more organized now? P: Definitely! It feels much neater and less cluttered. F: It's so satisfying when things are in order, right? Have any other plans for organizing your space? P: Planning to get new storage containers to arrange the kids' toys next."
2. recent two turns: "F: It's so satisfying when things are in order, right? Have any other plans for organizing your space? P: Planning to get new storage containers to arrange the kids' toys next."



{"performance level": {
"qp0": "NO performance difficulty (none, absent, negligible,... ) 0-4 %",
"qp1": "MILD difficulty (slight, low,...) 5-24 %",
"qp2": "MODERATE performance difficulty (medium, fair,...) 25-49 %",
"qp3": "SEVERE performance difficulty (high, extreme,...) 50-95 %",
"qp4": "COMPLETE performance difficulty (total,...) 96-100 %",
"qp8": "performance difficulty, not specified"     
}, 
"capacity level": {        
"qp0": "NO performance difficulty (none, absent, negligible,... ) 0-4 %",
"qp1": "MILD difficulty (slight, low,...) 5-24 %",
"qp2": "MODERATE performance difficulty (medium, fair,...) 25-49 %",
"qp3": "SEVERE performance difficulty (high, extreme,...) 50-95 %",
"qp4": "COMPLETE performance difficulty (total,...) 96-100 %",
"qp8": "performance difficulty, not specified"  
}
}

# %%
Prompting Instructions for Care-Taker (F) and Elderly Patient (P) Dialogue

Context: The dialogue revolves around the function category of "domestic life," which includes activities such as caring for one's belongings and space, acquiring food, clothing, and other necessities, household cleaning and repairing, and assisting others.

Objective: As the care-taker (F), your goal is to ask follow-up questions that monitor the function level of "domestic life" in terms of performance and capacity. Performance level refers to how well the activity is performed (observable), and capacity level refers to the patient's maximum potential or feelings about the activity (not physically observed).
Conversation Requirements:

    Focus more on the recent two turns of the conversation to generate the next question.
    Measure the function level of "domestic life" activities in terms of:
        Performance Level: Observable actions, e.g., how long an activity took, whether assistance was needed.
        Capacity Level: Patient's potential or feelings about the activity, e.g., perceived difficulty, physical demands.
    Performance and capacity levels should be categorized into three levels:
        Mild Difficulty: Slight, low
        Moderate Difficulty: Medium, fair
        Severe Difficulty: High, extreme

Format:

    Each turn is a single utterance by either the care-taker (F) or the elderly patient (P).
    Limit the conversation to 6-10 turns.

# %%
def category_testset(category, definition, allevents, MODEL = "gpt-3.5-turbo", dir= '../response_data/raw_conversations/'):
    """
    This is to generate dialogues acccording to categories in ICF by feeding the definitions of the each category to the prompt
    """
    count = 0
    data = {f"{category}": []}  
    text2write = ""
    for subcategory, events in allevents[category].items():

        query = [
            {"role": "system", "content": "Think as you are a real human."}, # Human
            {"role": "system", "content": """Generate one small and natural conversation without greetings by playing the roles of a friend (F) and an elderly patient (P). The conversation has around 10 to 30 utterances. Each utterance should be completed and has less than 20 tokens. The format is as below:
            F: utterance
            P: utternace
            F: utterance
            ...
            """}, # conversation format discription roles/
            
            {"role": "user", "content": f"The topic of the conversation is about {category} events. In terms of functioning, {category} is about {definition}. {category} events include {events}."}, # shifting details in the conversations
            
            {"role": "user", "content": f"The patient can talk with the friend about his/her daily life which can reflect his/her functioning in {category}. The friend should ask when and how the event occurs. "}# descripe category with definitions (listing events)
            ]
        
        num_20 = ["self-care","community, social and civic life"]
        num_30 = ["general tasks and demands", "mobility"]
        num_40 = ["learning and applying knowledge", "communication", "domestic life", "major life areas"]
        num_60 = ["interpersonal interactions and relationships"]
        if category in num_20:
            num = 20
        elif category in num_30:
            num = 30
        elif category in num_40:
            num = 40
        elif category in num_60:
            num = 60
        else:
            print(f"no such category: {category}")

        print(f"gpt-runing {category} - {subcategory}")
        # MODEL = "gpt-3.5-turbo"
        response_query = openai.ChatCompletion.create(
        model=MODEL,
        messages=query,
        temperature=1.5,
        max_tokens = 150,
        n = num,
        )

        print(f"gpt finished {category} - {subcategory}")
        
        # IPython.display.Markdown(response_query.choices[0]['message']['content'])
        time.sleep(60)
    
        for text in response_query.choices:
            conversation = text['message']['content']
            one_conversation = conversation + '\n'+'-'*10 +'\n'
            data[f"{category}"].append(conversation)
            text2write += one_conversation
            count += 1

    with open (f'{dir}{category}.txt','w') as tfile:
        tfile.write(text2write)

    with open (f'{dir}{category}.json','w', encoding='utf-8') as jfile:
            json.dump(data,jfile, ensure_ascii=False, indent=4)

    print(f"generated {count} {category} conversations")
    print("-"*30)
    print("\n")

# %%
count = 0
category = "mobility"
data = {f"{category}": []}
text2write = ""
for subcategory, events in allevents[category].items():

    query = [
        {"role": "system", "content": "Think as you are a real human."}, # Human
        {"role": "system", "content": """Generate one small and natural conversation without greetings by playing the roles of a friend (F) and an elderly patient (P). The conversation has around 10 to 30 utterances. Each utterance should be completed and has less than 20 tokens. The format is as below:
        F: utterance
        P: utternace
        F: utterance
        ...
        """}, # conversation format discription roles/
        
        {"role": "user", "content": f"The topic of the conversation is about {category} events. In terms of functioning, {category} is about {definition}. {category} events include {events}."}, # shifting details in the conversations
        
        {"role": "user", "content": f"The patient can talk with the friend about his/her daily life which can reflect his/her functioning in {category}. The friend should ask when and how the event occurs. "}# descripe category with definitions (listing events)
        ]
    
    num_20 = ["self-care","community, social and civic life"]
    num_30 = ["general tasks and demands", "mobility"]
    num_40 = ["learning and applying knowledge", "communication", "domestic life", "major life areas"]
    num_60 = ["interpersonal interactions and relationships"]
    if category in num_20:
        num = 20
    elif category in num_30:
        num = 30
    elif category in num_40:
        num = 40
    elif category in num_60:
        num = 60
    else:
        print(f"no such category: {category}")

    print(f"gpt-runing {category} - {subcategory}")
    # MODEL = "gpt-3.5-turbo"
    response_query = openai.ChatCompletion.create(
    model=MODEL,
    messages=query,
    temperature=1.5,
    max_tokens = 150,
    n = num,
    )

    print(f"gpt finished {category} - {subcategory}")
    
    # IPython.display.Markdown(response_query.choices[0]['message']['content'])
    time.sleep(60)

    for text in response_query.choices:
        conversation = text['message']['content']

# %%
def category_testset(category, definition, allevents, MODEL = "gpt-3.5-turbo", dir= '../response_data/raw_conversations/'):
    """
    This is to generate dialogues acccording to categories in ICF by feeding the definitions of the each category to the prompt
    """
    count = 0
    data = {f"{category}": []}  
    text2write = ""
    for subcategory, events in allevents[category].items():

        query = [
            {"role": "system", "content": "Think as you are a real human."}, # Human
            {"role": "system", "content": """Generate one small and natural conversation without greetings by playing the roles of a friend (F) and an elderly patient (P). The conversation has around 10 to 30 utterances. Each utterance should be completed and has less than 20 tokens. The format is as below:
            F: utterance
            P: utternace
            F: utterance
            ...
            """}, # conversation format discription roles/
            
            {"role": "user", "content": f"The topic of the conversation is about {category} events. In terms of functioning, {category} is about {definition}. {category} events include {events}."}, # shifting details in the conversations
            
            {"role": "user", "content": f"The patient can talk with the friend about his/her daily life which can reflect his/her functioning in {category}. The friend should ask when and how the event occurs. "}# descripe category with definitions (listing events)
            ]
        
        num_20 = ["self-care","community, social and civic life"]
        num_30 = ["general tasks and demands", "mobility"]
        num_40 = ["learning and applying knowledge", "communication", "domestic life", "major life areas"]
        num_60 = ["interpersonal interactions and relationships"]
        if category in num_20:
            num = 20
        elif category in num_30:
            num = 30
        elif category in num_40:
            num = 40
        elif category in num_60:
            num = 60
        else:
            print(f"no such category: {category}")

        print(f"gpt-runing {category} - {subcategory}")
        # MODEL = "gpt-3.5-turbo"
        response_query = openai.ChatCompletion.create(
        model=MODEL,
        messages=query,
        temperature=1.5,
        max_tokens = 150,
        n = num,
        )

        print(f"gpt finished {category} - {subcategory}")
        
        # IPython.display.Markdown(response_query.choices[0]['message']['content'])
        time.sleep(60)
    
        for text in response_query.choices:
            conversation = text['message']['content']
            one_conversation = conversation + '\n'+'-'*10 +'\n'
            data[f"{category}"].append(conversation)
            text2write += one_conversation
            count += 1

    with open (f'{dir}{category}.txt','w') as tfile:
        tfile.write(text2write)

    with open (f'{dir}{category}.json','w', encoding='utf-8') as jfile:
            json.dump(data,jfile, ensure_ascii=False, indent=4)

    print(f"generated {count} {category} conversations")
    print("-"*30)
    print("\n")

# %%
for category, definition, in ICF_defs.items():
    category_testset(category, definition, allevents)
print("done")
